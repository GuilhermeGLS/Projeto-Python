# %% [markdown]
# # Comparadores
#
# - "=="Igual
# - "!=" Diferente
# - ">" Maior que (>= maior ou igual que)
# - "<" Maior que (<= menor ou igual que)
# - "in" saber se contém algum x texto ou x simbolo dento de outro texto

# %%
vendafuncionario = 15000
vendaempresa = 500000
metafuncionario = 10000
metaempresa = 250000

if vendafuncionario >= metafuncionario and vendaempresa >= metaempresa:
    comissao = vendafuncionario * 0.03
    print(f"Parabéns bateu a meta sua comissão é de {comissao}")
# Out:
# Parabéns bateu a meta sua comissão é de 450.0
