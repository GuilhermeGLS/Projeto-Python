# %% [markdown]
# # Operações com Strings
#
# - str --> tranforme numero em string
# - in --> Verifica se tem um texeto dentro do outro
# - %s -> substitui textos
# - %d -> substitui numeros decimais

# %%
email1 = "guilherme@gmail.com"
email2 = "guilhermegmail.com"

print('@' in email1)
print('@' in email2)
# Out:
# True
# False
