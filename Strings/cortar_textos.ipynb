# %% [markdown]
# ### Forma Básica

# %%
precos = "Jan: 25, Fev: 27, Mar: 29"

preco_jan = precos[0:3]
print(preco_jan)
# Out:
# Jan

# %% [markdown]
# ### Posição Inicial e Final

# %% [markdown]
# ### Posição Inicial e Final com Step

# %%
codigo = "1.2.3.4,5,1,2.3.4,7.9"

pedaco_cod = codigo[::20]
print(pedaco_cod)
# Out:
# 19
